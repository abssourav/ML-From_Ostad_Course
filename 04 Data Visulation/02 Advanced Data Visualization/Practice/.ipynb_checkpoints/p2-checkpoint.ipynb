# %%
from sklearn.datasets import fetch_20newsgroups
print("ডাউনলোড শুরু হচ্ছে... দয়া করে অপেক্ষা করুন।")

newsgroups = fetch_20newsgroups(subset='train', categories=['sci.space'])

print("ডাউনলোড সম্পন্ন হয়েছে!")
print(f"মোট পোস্ট সংখ্যা: {len(newsgroups.data)}")
# Out:
# ডাউনলোড শুরু হচ্ছে... দয়া করে অপেক্ষা করুন।
# ডাউনলোড সম্পন্ন হয়েছে!
# মোট পোস্ট সংখ্যা: 593
